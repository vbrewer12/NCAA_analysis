# %%
#!pip install pandas
#!pip install requests
#!pip install sqlalchemy
#!pip install flask
# Out:
# Requirement already satisfied: pandas in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: requests in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from requests) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from requests) (2025.4.26)
# Requirement already satisfied: sqlalchemy in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (2.0.41)
# Requirement already satisfied: greenlet>=1 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from sqlalchemy) (3.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: flask in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (3.1.1)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (6.11.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\owner\anaconda3\envs\tf_env\lib\site-packages (from importlib-metadata>=3.6.0->flask) (3.21.0)

# %%
import requests
import pandas as pd
import numpy as np
import sqlalchemy as sql
from sqlalchemy import inspect

# %%
url = "https://api.sportradar.com/mlb/trial/v8/en/teams/eb21dadd-8f10-4095-8bf3-dfb3b779f107/profile.json"

headers = {
    "accept": "application/json",
    "x-api-key": "NYii5TfXY5KzhPP7RPf2Wj5eMOxiZPqFI1jDuKMB"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"name":"Astros","market":"Houston","abbr":"HOU","id":"eb21dadd-8f10-4095-8bf3-dfb3b779f107","founded":1962,"owner":"Jim Crane","general_manager":"Dana Brown","mascot":"Orbit","nicknames":"'Stros, Crush City","sponsor":"Oxy Energy","fight_song":"Go Go Astros","championships_won":2,"championship_seasons":"2017, 2022","conference_titles":5,"division_titles":14,"retired_numbers":"5, 7, 24, 25, 32, 33, 34, 40, 49, 42","playoff_appearances":18,"minorleague_affiliate":"Sugar Land Space Cowboys, Corpus Christi Hooks, Asheville Tourists, Fayetteville Woodpeckers","team_colors":[{"type":"primary","hex_color":"#002d62","rgb_color":{"red":0,"green":45,"blue":98}},{"type":"secondary","hex_color":"#eb6e1f","rgb_color":{"red":235,"green":110,"blue":31}}],"venue":{"name":"Daikin Park","market":"Houston","capacity":41000,"surface":"grass","address":"501 Crawford Street","city":"Houston","state":"TX","zip":"77002","country":"USA","id":"f0600f04-1386-4c61-a412-804960c46cb1","field_orientation":"N","stadium_type":"retractable","time_zone":"US/Central","location":{"lat":"29.7577058","lng":"-95.35453989999999"}},"league":{"alias":"AL","name":"American League","id":"2ea6efe7-2e21-4f29-80a2-0a24ad1f5f85"},"division":{"alias":"W","name":"West","id":"59d3a9b1-30a8-4a6a-b4e6-0fe63257d01b"},"staff":[{"full_name":"Bill Murphy","first_name":"Bill","last_name":"Murphy","position":"Pitching Coach","id":"a4a4b8e6-035c-4a0e-be4c-9235eb88c717"},{"full_name":"Troy Snitker","first_name":"Troy","last_name":"Snitker","position":"Hitting Coach","id":"bdf750ad-0db8-4de8-9ae8-c126c671a6c9"},{"full_name":"Joe Espada","first_name":"Joe","last_name":"Espada","position":"Manager","id":"d4ef728b-3963-4a67-9a99-b54472ed836f"},{"full_name":"Joshua Miller","first_name":"Joshua","last_name":"Miller","position":"Pitching Coach","id":"f43d112b-a380-4c27-acdc-011cc35f6611"},{"full_name":"Alex Cintron","first_name":"Alex","last_name":"Cintron","position":"Hitting Coach","id":"ff5f0ec1-fb3d-41f3-b009-dbef171781b4"}],"players":[{"id":"64c76a31-1a6a-4cf3-a871-bd83c41fa6ef","status":"A","position":"C","primary_position":"C","first_name":"Victor","last_name":"Caratini","preferred_name":"Victor","jersey_number":"17","full_name":"Victor Caratini","height":"72","weight":"225","throw_hand":"R","bat_hand":"B","college":"Miami Dade College","high_school":"Puerto Rico Baseball Academy (PRI)","birthdate":"1993-08-17","birthcountry":"PRI","birthcity":"Coamo","pro_debut":"2017-06-28","updated":"2025-03-26T20:40:56+00:00","salary":6000000,"rookie_year":2018,"reference":"605170","active":true},{"id":"ca2dd733-f69d-481c-bffe-78219a34df21","status":"A","position":"C","primary_position":"C","first_name":"Yainer","last_name":"Diaz","preferred_name":"Yainer","jersey_number":"21","full_name":"Yainer Diaz","height":"71","weight":"195","throw_hand":"R","bat_hand":"R","birthdate":"1998-09-21","birthcountry":"DOM","birthcity":"Azua","pro_debut":"2022-09-02","updated":"2025-05-17T19:52:47+00:00","salary":805600,"rookie_year":2023,"reference":"673237","active":true},{"id":"ac879004-2296-41c0-8b8c-42eaec3c20c2","status":"A","position":"C","primary_position":"C","first_name":"César","last_name":"Salazar","preferred_name":"César","jersey_number":"18","full_name":"César Salazar","height":"69","weight":"198","throw_hand":"R","bat_hand":"L","college":"Arizona","high_school":"Sahuaro (AZ)","birthdate":"1996-03-15","birthcountry":"MEX","birthcity":"Hermosillo","pro_debut":"2023-04-02","updated":"2025-05-17T19:56:43+00:00","salary":604728,"rookie_year":2023,"reference":"663967","active":true},{"id":"b383a233-3917-4371-9c49-683505c980d8","status":"A","position":"IF","primary_position":"RF","first_name":"Zachary","last_name":"Dezenzo","preferred_name":"Zach","jersey_number":"9","full_name":"Zach Dezenzo","height":"77","weight":"220","throw_hand":"R","bat_hand":"R","college":"Ohio State","high_school":"Marlington (OH)","birthdate":"2000-05-11","birthstate":"OH","birthcountry":"USA","birthcity":"Canton","pro_debut":"2024 ...
